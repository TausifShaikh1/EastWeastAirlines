# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'/data/notebook_files/EastWestAirlines.csv')
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID#</th>
#       <th>Balance</th>
#       <th>Qual_miles</th>
#       <th>cc1_miles</th>
#       <th>cc2_miles</th>
#       <th>cc3_miles</th>
#       <th>Bonus_miles</th>
#       <th>Bonus_trans</th>
#       <th>Flight_miles_12mo</th>
#       <th>Flight_trans_12</th>
#       <th>Days_since_enroll</th>
#       <th>Award?</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>28143</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>174</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>7000</td>
# ...

# %%
a = df.head(20)
a
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID#</th>
#       <th>Balance</th>
#       <th>Qual_miles</th>
#       <th>cc1_miles</th>
#       <th>cc2_miles</th>
#       <th>cc3_miles</th>
#       <th>Bonus_miles</th>
#       <th>Bonus_trans</th>
#       <th>Flight_miles_12mo</th>
#       <th>Flight_trans_12</th>
#       <th>Days_since_enroll</th>
#       <th>Award?</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>28143</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>174</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>7000</td>
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
enc=OneHotEncoder()
enc
enc_df=pd.DataFrame(enc.fit_transform(a.iloc[:,2:]).toarray())
enc_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#       <th>...</th>
#       <th>64</th>
#       <th>65</th>
#       <th>66</th>
#       <th>67</th>
#       <th>68</th>
#       <th>69</th>
#       <th>70</th>
#       <th>71</th>
#       <th>72</th>
#       <th>73</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>1.0</td>
# ...

# %%
x = a.Balance
y = a.Days_since_enroll

plt.figure(figsize=(6,5)) # Corrected line
plt.plot(x, marker='D')
plt.plot(y, marker='o')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize a scaler
scaler = MinMaxScaler()

# Find numerical columns
numeric_cols = df.select_dtypes(include=np.number).columns

# Apply scaling to numeric columns
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID#</th>
#       <th>Balance</th>
#       <th>Qual_miles</th>
#       <th>cc1_miles</th>
#       <th>cc2_miles</th>
#       <th>cc3_miles</th>
#       <th>Bonus_miles</th>
#       <th>Bonus_trans</th>
#       <th>Flight_miles_12mo</th>
#       <th>Flight_trans_12</th>
#       <th>Days_since_enroll</th>
#       <th>Award?</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.000000</td>
#       <td>0.016508</td>
#       <td>0.0</td>
#       <td>0.00</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.000660</td>
#       <td>0.011628</td>
#       <td>0.000000</td>
# ...

# %%
from sklearn.preprocessing import StandardScaler

# Select a subset of the data
df_subset = df[df.columns[1:6]]

# Apply Standard Scalar to the subset of data
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df_subset), columns=df_subset.columns)
df_scaled
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Balance</th>
#       <th>Qual_miles</th>
#       <th>cc1_miles</th>
#       <th>cc2_miles</th>
#       <th>cc3_miles</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-0.451141</td>
#       <td>-0.186299</td>
#       <td>-0.769578</td>
#       <td>-0.098242</td>
#       <td>-0.062767</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-0.539457</td>
#       <td>-0.186299</td>
#       <td>-0.769578</td>
#       <td>-0.098242</td>
#       <td>-0.062767</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-0.320031</td>
#       <td>-0.186299</td>
# ...

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# Create linkage matrix
linked = linkage(df_scaled, 'ward')

# Create dendrogram
plt.figure(figsize=(10, 7))
dendrogram(linked, truncate_mode='level', p=5)
plt.title('Dendrogram')
plt.ylabel('Euclidean distances')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
import seaborn as sns

# Create and fit an AgglomerativeClustering model
clustering = AgglomerativeClustering().fit(df_scaled)
df_scaled['cluster'] = clustering.labels_

# Plot the clusters
plt.figure(figsize=(10,15)) 
sns.scatterplot(data=df_scaled, x='Balance', y='Qual_miles', hue='cluster')

plt.title('Agglomerative Clustering')
plt.show()

# From the plot, we can observe that the agglomerative clustering algorithm separates the dataset into reasonable clusters.
# Another insight would be gaining an understanding of the patterns in the dataset, numberOf clusters, decision boundaries, etc.
# Here we can see that most of the balance that qual_miles have is concetrated from 0 to 4, and stretches from 0 till 10.0.
# Later the data is way more distributed in qual_miles and balance
